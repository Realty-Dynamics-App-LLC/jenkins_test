# %%
import os
import openpyxl
import xlrd
import pandas as pd
import json
from dbfread import DBF

# %%
root = 'data/latest_sales_data'

# Initialize an empty dictionary to hold dataframes
dataframes = {}

# Define a function to load a file into a dataframe
def load_file_to_df(path, filename):
    if filename.endswith('.xlsx') or filename.endswith('.xls'):
        return pd.read_excel(os.path.join(path, filename))
    elif filename.endswith('.csv'):
        return pd.read_csv(os.path.join(path, filename), on_bad_lines='skip')
    elif filename.endswith('.json') or filename.endswith('.geojson'):
        with open(os.path.join(path, filename)) as f:
            data = json.load(f)
        return pd.json_normalize(data)
    elif filename.endswith('.dbf'):
        dbf = DBF(os.path.join(path, filename))
        return pd.DataFrame(iter(dbf))
    else:
        return None

# Walk through each directory
for root, dirs, files in os.walk(root):
    for file in files:
        # Ignore metadata files
        if 'metadata' not in file.lower():
            print(f'Loading {file} from {root}')
            df = load_file_to_df(root, file)
            if df is not None:
                # Use the directory name as the key
                key = os.path.basename(root)
                # If key already exists, append the new dataframe
                if key in dataframes:
                    dataframes[key] = pd.concat([dataframes[key], df])
                else:
                    dataframes[key] = df
# Out:
# Loading Alachua.xlsx from data/latest_sales_data/Alachua County
# Loading 2024 Sales.xlsx from data/latest_sales_data/Baker County
# Loading 2023 Sales.xlsx from data/latest_sales_data/Baker County
# Loading Bay County.xlsx from data/latest_sales_data/Bay County
# /home/apratim/miniconda3/envs/geo_env/lib/python3.12/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# Loading Bradford.csv from data/latest_sales_data/Bradford County
# Loading 2024 Sales Data.xlsx from data/latest_sales_data/Calhoun County
# Loading 2023 Sales Data.xlsx from data/latest_sales_data/Calhoun County
# Loading Charlotte County.xls from data/latest_sales_data/Charlotte County
# Loading Citrus2024.xlsx from data/latest_sales_data/Citrus County
# Loading Citrus2023.xlsx from data/latest_sales_data/Citrus County
# Loading 2024 Sales YTD.xlsx from data/latest_sales_data/Clay County
# Loading Collier.csv from data/latest_sales_data/Collier County
# Loading Columbia 2024 .xlsx from data/latest_sales_data/Columbia County
# Loading Colombia 2023 .xlsx from data/latest_sales_data/Columbia County
# Loading Desoto 2024.xlsx from data/latest_sales_data/DeSoto County
# Loading Desoto 2023 .xlsx from data/latest_sales_data/DeSoto County
# Loading Dixie.xlsx from data/latest_sales_data/Dixie County
# Loading Escambia.csv from data/latest_sales_data/Escambia County
# Loading Flagler.xlsx from data/latest_sales_data/Flagler County
# Loading Franklin.xlsx from data/latest_sales_data/Franklin County
# Loading Gadsen.xlsx from data/latest_sales_data/Gadsen County
# Loading Gilchrist.xlsx from data/latest_sales_data/Gilchrist County
# Loading Glades.xlsx from data/latest_sales_data/Glades County
# Loading Gulf.xlsx from data/latest_sales_data/Gulf County
# Loading Hamilton.xlsx from data/latest_sales_data/Hamilton County
# Loading Hardee.xlsx from data/latest_sales_data/Hardee County
# Loading Hendry.xlsx from data/latest_sales_data/Hendry County
# Loading Highland.csv from data/latest_sales_data/Highland County
# Loading allsales.dbf from data/latest_sales_data/Hillsborough County
# Loading Holmes.xlsx from data/latest_sales_data/Holmes County
# Loading Indianriver.xlsx from data/latest_sales_data/Indian River County
# Loading Jackson.xlsx from data/latest_sales_data/Jackson County
# Loading Jefferson.xlsx from data/latest_sales_data/Jefferson County
# Loading Lake 2023.xlsx from data/latest_sales_data/Lake County
# Loading Leon.xlsx from data/latest_sales_data/Leon County

# %%
for key in dataframes.keys():
    print(key)
    dataframes[key].info(show_counts=True)
# Out:
# Alachua County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4293 entries, 0 to 4292
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Parcel ID                4293 non-null   object
#  1   Address                  3958 non-null   object
#  2   Sale Date                4293 non-null   object
#  3   Sale Price               4293 non-null   object
#  4   Qualified Sales          4293 non-null   object
#  5   Reason                   4293 non-null   object
#  6   Book                     4293 non-null   int64
#  7   Page                     4293 non-null   object
#  8   Instrument               4293 non-null   object
#  9   Acres                    4293 non-null   float64
#  10  Property Use             4283 non-null   object
#  11  Tax District             4293 non-null   object
#  12  Just Value               4293 non-null   object
#  13  Year  Built              3276 non-null   float64
#  14  Exterior Wall            2891 non-null   object
#  15  Heated Sq Ft             3276 non-null   float64
#  16  Price Per  Heated SqFt   4293 non-null   object
#  17  Neighborhood             3933 non-null   object
#  18  Subdivision              3399 non-null   object
#  19  Sec/Twp/Rng              4283 non-null   object
#  20  Vacant                   3933 non-null   object
#  21  Land Use                 3912 non-null   object
#  22  Building Use             3287 non-null   object
#  23  Bedrooms                 3148 non-null   object
#  24  Bathrooms                3161 non-null   object
#  25  Zipcode                  3968 non-null   float64
#  26  Mailing Address          4293 non-null   object
# dtypes: float64(4), int64(1), object(22)
# memory usage: 905.7+ KB
# Baker County
# <class 'pandas.core.frame.DataFrame'>
# Index: 851 entries, 0 to 760
# Data columns (total 20 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Parcel #                         851 non-null    object
#  1   Date of Sale                     851 non-null    datetime64[ns]
#  2   Sales Price                      851 non-null    int64
#  3   Instrument Number                851 non-null    int64
#  4   Vac/Imp Code                     851 non-null    object
#  5   Use Code                         845 non-null    float64
#  6   Taxing District                  851 non-null    object
#  7   Owner Name 1                     851 non-null    object
#  8   Owner Name 2                     428 non-null    object
#  9   Site Address                     851 non-null    object
#  10  Primary Building Use Code        557 non-null    float64
#  11  Primary Building Adjusted Sq Ft  557 non-null    float64
#  12  Primary Building Heated Sq Ft    557 non-null    float64
#  13  Primary Building Year Built      557 non-null    float64
#  14  land_units                       851 non-null    float64
#  15  land_type                        851 non-null    object
#  16  Market Value                     851 non-null    int64
#  17  Building Value                   851 non-null    int64
#  18  Extra Feature Value              851 non-null    int64
#  19  Land Value                       851 non-null    int64
# dtypes: datetime64[ns](1), float64(6), int64(6), object(7)
# memory usage: 139.6+ KB
# Bay County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19469 entries, 0 to 19468
# Data columns (total 29 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   PIN_DSP     19469 non-null  object
#  1   OWNER_NAME  19469 non-null  object
#  2   ADDRESS_1   19469 non-null  object
#  3   ADDRESS_2   2409 non-null   object
#  4   ADDRESS_3   113 non-null    object
#  5   CITY_NAME   19466 non-null  object
#  6   ST          19462 non-null  object
#  7   ZIPCODE     19466 non-null  object
#  8   USEDESC     19469 non-null  object
#  9   TAXDIST     19469 non-null  int64
#  10  HOUSE_NO    18251 non-null  object
#  11  STREET      19469 non-null  object
#  12  ST_MD       18575 non-null  object
#  13  ST_CITY     19469 non-null  object
#  14  ST_ZIP5     19469 non-null  int64
#  15  SASEQNO     19469 non-null  int64
#  16  SARBOOK     19469 non-null  int64
#  17  SARPAGE     19469 non-null  int64
#  18  SASINS      19469 non-null  object
#  19  SAGNTR      19469 non-null  object
#  20  SAGNTE      19467 non-null  object
#  21  SAPYR       19469 non-null  int64
#  22  SARDATE     19469 non-null  int64
#  23  Sale Date   19469 non-null  datetime64[ns]
#  24  SAPRICE     19469 non-null  int64
#  25  TOTACRES    19469 non-null  float64
#  26  LEGL1       19469 non-null  object
#  27  LEGL2       19469 non-null  object
#  28  LEGL3       19459 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(8), object(19)
# memory usage: 4.3+ MB
# Bradford County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1698 entries, 0 to 1697
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sale_Date    1698 non-null   object
#  1   Price        1698 non-null   int64
#  2   V/I          1698 non-null   object
#  3   Qual         1698 non-null   object
#  4   OR           1697 non-null   object
#  5   Book         1500 non-null   float64
#  6   Page         1498 non-null   float64
#  7   Name         1698 non-null   object
#  8   Street       1690 non-null   object
#  9   SType        1260 non-null   object
#  10  PIN          1698 non-null   object
#  11  Total_Acres  1698 non-null   float64
#  12  Use          1698 non-null   object
#  13  Appr_Value   1698 non-null   int64
#  14  Tax_Value    1698 non-null   int64
# dtypes: float64(3), int64(3), object(9)
# memory usage: 199.1+ KB
# Calhoun County
# <class 'pandas.core.frame.DataFrame'>
# Index: 1349 entries, 0 to 1147
# Data columns (total 22 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   conf_flg      1349 non-null   int64
#  1   parcel_id     1349 non-null   int64
#  2   dsp_strap     1349 non-null   object
#  3   use_cd        1349 non-null   int64
#  4   or_bk         1349 non-null   int64
#  5   or_pg         1349 non-null   int64
#  6   instr_num     0 non-null      float64
#  7   transfer_fee  1343 non-null   float64
#  8   dos           1349 non-null   datetime64[ns]
#  9   price         1349 non-null   int64
#  10  bxl_val       1349 non-null   int64
#  11  instr_cd      1349 non-null   object
#  12  dscr          1349 non-null   object
#  13  trns_cd       1346 non-null   float64
#  14  dscr.1        1346 non-null   object
#  15  qu_cd         1346 non-null   object
#  16  ncon_val      1349 non-null   int64
#  17  demo_val      1349 non-null   int64
#  18  chg_cd        17 non-null     float64
#  19  dscr.2        17 non-null     object
#  20  Grantor       1349 non-null   object
#  21  Grantee       1349 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(9), object(8)
# memory usage: 242.4+ KB
# Charlotte County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11916 entries, 0 to 11915
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   PADStreetNumber        11769 non-null  float64
#  1    PADStreetName         11769 non-null  object
#  2   PADCity                11769 non-null  object
#  3    PADZip                11769 non-null  float64
#  4   Account                11916 non-null  int64
#  5   Taxyear                11916 non-null  int64
#  6   SaleDate               11916 non-null  datetime64[ns]
#  7   SalePrice              11916 non-null  int64
#  8   Landuse                11916 non-null  object
#  9   landusecode            11916 non-null  int64
#  10  CertifiedJustValue     11916 non-null  int64
#  11  CertifiedTaxableValue  11916 non-null  int64
#  12   certifyyear           11916 non-null  int64
#  13  ShortLegal             11916 non-null  object
#  14  YearBuilt              11916 non-null  int64
#  15  OwnersName             11898 non-null  object
#  16  MailingAddress         142 non-null    object
#  17  Suite                  2321 non-null   object
#  18  MailingAddress2        11898 non-null  object
#  19  City                   11898 non-null  object
#  20  State                  11805 non-null  object
#  21  Country                198 non-null    object
#  22  ZipCode                11804 non-null  object
#  23  BusinessName           532 non-null    object
#  24  zoning                 11916 non-null  object
#  25  book                   11916 non-null  int64
#  26  page                   11916 non-null  int64
#  27  salecode               11916 non-null  object
#  28  ACarea                 11916 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(11), object(15)
# memory usage: 2.6+ MB
# Citrus County
# <class 'pandas.core.frame.DataFrame'>
# Index: 22250 entries, 0 to 19132
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ALTKEY     22250 non-null  int64
#  1   PARCEL ID  22250 non-null  object
#  2   PC         22250 non-null  int64
#  3   NCD        22250 non-null  int64
#  4   OWNER      22250 non-null  object
#  5   ADDR3      22242 non-null  object
#  6   ADDR4      76 non-null     object
#  7   ZIP        22250 non-null  object
#  8   BOOK       22250 non-null  int64
#  9   PAGE       22250 non-null  int64
#  10  SALE_DATE  22250 non-null  object
#  11  VAC-IMP    22250 non-null  object
#  12  INCD       22250 non-null  int64
#  13  QUALIFIED  22247 non-null  object
#  14  DOR_CODE   22247 non-null  float64
#  15  PRICE      22250 non-null  int64
# dtypes: float64(1), int64(7), object(8)
# memory usage: 2.9+ MB
# Clay County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356 entries, 0 to 355
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Parcel ID   356 non-null    object
#  1   Sale Date   356 non-null    datetime64[ns]
#  2   Sale Price  356 non-null    int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 8.5+ KB
# Collier County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29934 entries, 0 to 29933
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    29934 non-null  int64
#  1   parcelid    29934 non-null  int64
#  2   seqno       29934 non-null  int64
#  3   salebook    29934 non-null  int64
#  4   salepage    29934 non-null  int64
#  5   saledate    29934 non-null  int64
#  6   sale date   1948 non-null   object
#  7   saleamount  29934 non-null  object
#  8   qualcode    29934 non-null  int64
#  9   trancode    29934 non-null  int64
# dtypes: int64(8), object(2)
# memory usage: 2.3+ MB
# Columbia County
# <class 'pandas.core.frame.DataFrame'>
# Index: 2044 entries, 0 to 1640
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sale_Date    2044 non-null   datetime64[ns]
#  1   Price        2044 non-null   int64
#  2   V/I          2044 non-null   object
#  3   Qual         2044 non-null   object
#  4   OR           2044 non-null   object
#  5   Book         2044 non-null   int64
#  6   Page         2044 non-null   int64
#  7   Name         2044 non-null   object
#  8   Street       1658 non-null   object
#  9   SType        1533 non-null   object
#  10  PIN          2044 non-null   object
#  11  Total_Acres  2044 non-null   float64
#  12  Use          2044 non-null   object
#  13  Appr_Value   2044 non-null   int64
#  14  Tax_Value    2044 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(8)
# memory usage: 255.5+ KB
# DeSoto County
# <class 'pandas.core.frame.DataFrame'>
# Index: 1189 entries, 0 to 1023
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sale_Date    1189 non-null   datetime64[ns]
#  1   Price        1189 non-null   int64
#  2   V/I          1189 non-null   object
#  3   Qual         1189 non-null   object
#  4   OR           1189 non-null   object
#  5   Book         1189 non-null   int64
#  6   Page         1189 non-null   int64
#  7   Name         1189 non-null   object
#  8   Street       1189 non-null   object
#  9   SType        920 non-null    object
#  10  PIN          1189 non-null   object
#  11  Total_Acres  1189 non-null   float64
#  12  Use          1189 non-null   object
#  13  Appr_Value   1189 non-null   int64
#  14  Tax_Value    1189 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(8)
# memory usage: 148.6+ KB
# Dixie County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 527 entries, 0 to 526
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Parcel ID         527 non-null    object
#  1   Address           527 non-null    object
#  2   Owner Name        527 non-null    object
#  3   Sale Date         527 non-null    object
#  4   Sale Price        527 non-null    object
#  5   Qualified Sales   527 non-null    object
#  6   Reason            527 non-null    object
#  7   Acres             527 non-null    float64
#  8   Parcel  Class     527 non-null    object
#  9   Tax District      527 non-null    object
#  10  Assessed  Value   527 non-null    object
#  11  Square Ft         245 non-null    float64
#  12  Sec/Twp/Rng       527 non-null    object
# dtypes: float64(2), object(11)
# memory usage: 53.7+ KB
# Escambia County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13088 entries, 0 to 13087
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Account         13088 non-null  int64
#  1   Parcel ID       13088 non-null  object
#  2   DorCd           13088 non-null  int64
#  3   Subdivision     11164 non-null  object
#  4   Sale Date       13088 non-null  object
#  5   Sale Price      13088 non-null  int64
#  6   Book            13088 non-null  int64
#  7   Page            13088 non-null  int64
#  8   Qual. Status    13088 non-null  object
#  9   Vac<br/>/Imprv  13088 non-null  object
#  10  Instr Type      13088 non-null  object
#  11  Parcel Count    13088 non-null  int64
# dtypes: int64(6), object(6)
# memory usage: 1.2+ MB
# Flagler County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2311 entries, 0 to 2310
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Parcel Number    2311 non-null   object
#  1   Address          2239 non-null   object
#  2   Owner Name       2306 non-null   object
#  3   Sale Date        2311 non-null   object
#  4   Sale Price       2311 non-null   object
#  5   Qualified Sales  2311 non-null   object
#  6   Book             2306 non-null   float64
#  7   Page             2306 non-null   float64
#  8   Instrument       2311 non-null   object
#  9   Acres            2311 non-null   float64
#  10  Tax District     2311 non-null   int64
#  11  Just  Value      2311 non-null   object
#  12  Year  Built      1273 non-null   float64
#  13  Square Ft        1273 non-null   float64
#  14  Sec/Twp/Rng      2311 non-null   object
#  15  Vacant/Impr      2311 non-null   object
#  16  Land Value       2311 non-null   object
#  17  Owner Name 2     238 non-null    object
#  18  Owner Address 1  2306 non-null   object
#  19  Owner Address 2  318 non-null    object
#  20  Owner C/S/Z      2306 non-null   object
# dtypes: float64(5), int64(1), object(15)
# memory usage: 379.3+ KB
# Franklin County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1414 entries, 0 to 1413
# Data columns (total 62 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Property ID                      1414 non-null   object
#  1   Sale Date                        1414 non-null   datetime64[ns]
#  2   Sale Price                       1414 non-null   int64
#  3   Adj Sale Price                   1 non-null      float64
#  4   Instrument Number                1414 non-null   int64
#  5   Book                             1414 non-null   int64
#  6   Page                             1414 non-null   int64
#  7   Instrument Code                  1414 non-null   object
#  8   Instrument Description           1414 non-null   object
#  9   Transaction Code                 1414 non-null   int64
#  10  Transaction Description          1414 non-null   object
#  11  Red Flag                         0 non-null      float64
#  12  Seller Name                      1413 non-null   object
#  13  Buyer Name                       1414 non-null   object
#  14  Sale Note                        56 non-null     object
#  15  Site Address                     1255 non-null   object
#  16  Site City                        764 non-null    object
#  17  Site State                       43 non-null     object
#  18  Site Zip                         1343 non-null   float64
#  19  Owner Name                       1414 non-null   object
#  20  Mail C/O                         5 non-null      object
#  21  Mail Address 1                   1414 non-null   object
#  22  Mail Address 2                   652 non-null    object
#  23  Mail Address 3                   4 non-null      object
#  24  Mail City                        1414 non-null   object
#  25  Mail State                       1414 non-null   object
#  26  Mail Zip                         1414 non-null   object
#  27  Primary Building Num             627 non-null    object
#  28  Primary Building Area            627 non-null    float64
#  29  Primary Building Year Built      627 non-null    float64
#  30  Primary Building WAY             627 non-null    float64
#  31  Building Count                   1414 non-null   int64
#  32  Parcel Size                      1411 non-null   float64
#  33  Parcel Size Units                1411 non-null   object
#  34  Taxable Value                    1414 non-null   int64
#  35  Net Assessed Value               1414 non-null   int64
#  36  Use Code                         1414 non-null   int64
#  37  Use Code Description             1414 non-null   object
#  38  Subdivision Code                 10 non-null     float64
#  39  Subdivision                      10 non-null     object
#  40  Tax Year (h)                     1404 non-null   float64
#  41  Taxable Value (h)                1404 non-null   float64
#  42  Assessed Exemption Value (h)     1404 non-null   float64
#  43  Net Assessed Value (h)           1404 non-null   float64
#  44  Building Value (h)               1404 non-null   float64
#  45  Extra Features Value (h)         1404 non-null   float64
#  46  Total Land Value (h)             1404 non-null   float64
#  47  Personal Property Value (h)      1404 non-null   float64
#  48  New Personal Property Value (h)  1404 non-null   float64
#  49  New Improvements Value (h)       1404 non-null   float64
#  50  New Land Value (h)               1404 non-null   float64
#  51  AG land value (h)                1404 non-null   float64
#  52  Sale Year                        1414 non-null   int64
#  53  Taxable Value (Sale Year)        1178 non-null   float64
#  54  Net Assessed Value (Sale Year)   1178 non-null   float64
#  55  Tax District Code                1414 non-null   int64
#  56  Tax District                     1414 non-null   object
#  57  Use Code at Sale                 1414 non-null   int64
#  58  Use Description at Sale          1414 non-null   object
#  59  Zoning at Sale                   3 non-null      float64
#  60  Parcel Land Units                1414 non-null   float64
#  61  Parcel Land Units Code           1411 non-null   object
# dtypes: datetime64[ns](1), float64(24), int64(12), object(25)
# memory usage: 685.0+ KB
# Gadsen County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 533 entries, 0 to 532
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Parcel ID             533 non-null    object
#  1   Address               533 non-null    object
#  2   Sale Date             533 non-null    object
#  3   Sale Price            533 non-null    object
#  4   Qualified Sales       533 non-null    object
#  5   Book                  533 non-null    int64
#  6   Page                  533 non-null    int64
#  7   Instrument            533 non-null    object
#  8   Acres                 533 non-null    float64
#  9   Tax District          533 non-null    object
#  10  Year  Built           311 non-null    float64
#  11  Square Ft             311 non-null    float64
#  12  Sec/Twp/Rng           508 non-null    object
#  13  Sale  Type Alternate  533 non-null    object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 58.4+ KB
# Gilchrist County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 542 entries, 0 to 541
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Parcel ID             542 non-null    object
#  1   Address               542 non-null    object
#  2   Sale Date             542 non-null    object
#  3   Sale Price            542 non-null    object
#  4   Qualified Sales       542 non-null    object
#  5   Book                  0 non-null      float64
#  6   Page                  0 non-null      float64
#  7   Instrument            542 non-null    object
#  8   Ref Number            542 non-null    int64
#  9   Acres                 542 non-null    float64
#  10  Tax District          542 non-null    int64
#  11  Year  Built           224 non-null    float64
#  12  Square Ft             224 non-null    float64
#  13  Sec/Twp/Rng           542 non-null    object
#  14  Sale  Type Alternate  542 non-null    object
# dtypes: float64(5), int64(2), object(8)
# memory usage: 63.6+ KB
# Glades County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513 entries, 0 to 512
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Parcel ID             513 non-null    object
#  1   Address               513 non-null    object
#  2   Sale Date             513 non-null    object
#  3   Sale Price            513 non-null    object
#  4   Qualified Sales       513 non-null    object
#  5   Book                  513 non-null    int64
#  6   Page                  513 non-null    int64
#  7   Instrument            513 non-null    object
#  8   Acres                 513 non-null    float64
#  9   Tax District          513 non-null    int64
#  10  Year  Built           318 non-null    float64
#  11  Square Ft             318 non-null    float64
#  12  Sec/Twp/Rng           513 non-null    object
#  13  Sale  Type Alternate  513 non-null    object
# dtypes: float64(3), int64(3), object(8)
# memory usage: 56.2+ KB
# Gulf County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 603 entries, 0 to 602
# Data columns (total 42 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Parcel ID                   603 non-null    object
#  1   Address                     602 non-null    object
#  2   Owner Name                  603 non-null    object
#  3   Owner Address               603 non-null    object
#  4   Sale Date                   603 non-null    object
#  5   Sale Price                  603 non-null    object
#  6   Qualified Sales             603 non-null    object
#  7   Book                        603 non-null    int64
#  8   Page                        603 non-null    int64
#  9   Instrument                  603 non-null    object
#  10  Acres                       603 non-null    float64
#  11  Tax District                603 non-null    int64
#  12  Year  Built                 201 non-null    float64
#  13  Square Ft                   201 non-null    float64
#  14  Sec/Twp/Rng                 603 non-null    object
#  15  Sale  Type Alternate        603 non-null    object
#  16  Homestead                   603 non-null    object
#  17  Last Sale Date              603 non-null    object
#  18  Tax District Code           603 non-null    int64
#  19  Use Code                    603 non-null    int64
#  20  Owner Zip                   601 non-null    object
#  21  Owner State                 601 non-null    object
#  22  Owner City                  603 non-null    object
#  23  Owner Address 1             603 non-null    object
#  24  Owner Address 2             24 non-null     object
#  25  Site Zip                    0 non-null      float64
#  26  Site City                   603 non-null    object
#  27  Grantor                     603 non-null    object
#  28  Grantee                     603 non-null    object
#  29  Instrument Type             603 non-null    object
#  30  Tax Year                    603 non-null    int64
#  31  Extra Features Value        603 non-null    int64
#  32  Building Value              603 non-null    int64
#  33  Land Value                  603 non-null    int64
#  34  AgLand Value                603 non-null    int64
#  35  Market Land Value           603 non-null    int64
#  36  Market Value                603 non-null    int64
#  37  Assessed Value              603 non-null    int64
#  38  Exemption Value             603 non-null    int64
#  39  Taxable Value               603 non-null    int64
#  40  Save Our Homes Portability  603 non-null    int64
#  41  Building Count              603 non-null    int64
# dtypes: float64(4), int64(17), object(21)
# memory usage: 198.0+ KB
# Hamilton County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 482 entries, 0 to 481
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Parcel ID             482 non-null    object
#  1   Address               183 non-null    object
#  2   Sale Date             482 non-null    object
#  3   Sale Price            482 non-null    object
#  4   Qualified Sales       482 non-null    object
#  5   Book                  482 non-null    int64
#  6   Page                  482 non-null    int64
#  7   Instrument            482 non-null    object
#  8   Acres                 482 non-null    float64
#  9   Tax District          482 non-null    int64
#  10  Year  Built           102 non-null    float64
#  11  Square Ft             121 non-null    float64
#  12  Sec/Twp/Rng           482 non-null    object
#  13  Sale  Type Alternate  482 non-null    object
# dtypes: float64(3), int64(3), object(8)
# memory usage: 52.8+ KB
# Hardee County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630 entries, 0 to 629
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Parcel ID             630 non-null    object
#  1   Address               630 non-null    object
#  2   Owner Name            630 non-null    object
#  3   Sale Date             630 non-null    object
#  4   Sale Price            630 non-null    object
#  5   Qualified Sales       630 non-null    object
#  6   Book                  0 non-null      float64
#  7   Page                  0 non-null      float64
#  8   Instrument Number     630 non-null    int64
#  9   Acres                 630 non-null    float64
#  10  Tax District          630 non-null    int64
#  11  Just Value            630 non-null    object
#  12  Year  Built           282 non-null    float64
#  13  Square Ft             282 non-null    float64
#  14  Sec/Twp/Rng           630 non-null    object
#  15  Sale  Type Alternate  630 non-null    object
#  16  MailingAddress        630 non-null    object
# dtypes: float64(5), int64(2), object(10)
# memory usage: 83.8+ KB
# Hendry County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2121 entries, 0 to 2120
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Parcel ID                2121 non-null   object
#  1   Address                  2117 non-null   object
#  2   Sale Date                2121 non-null   object
#  3   Sale Price               2121 non-null   object
#  4   Qualified Sales          2121 non-null   object
#  5   Reason                   2121 non-null   object
#  6   Book                     2115 non-null   float64
#  7   Page                     2115 non-null   float64
#  8   Instrument               2121 non-null   object
#  9   Acres                    2121 non-null   float64
#  10  Just Value               2121 non-null   object
#  11  Year  Built              967 non-null    float64
#  12  Heated Sq Ft             967 non-null    float64
#  13  Price Per  Heated SqFt   2121 non-null   object
#  14  Neighborhood             2121 non-null   object
#  15  Subdivision              1428 non-null   object
#  16  Sec/Twp/Rng              2121 non-null   object
#  17  Vacant                   2121 non-null   object
#  18  Land Use                 2098 non-null   object
#  19  Building Use             957 non-null    object
#  20  Bedrooms                 831 non-null    float64
#  21  Bathrooms                831 non-null    float64
#  22  Zipcode                  2063 non-null   float64
#  23  Prop Use                 2098 non-null   object
#  24  Community                2071 non-null   object
# dtypes: float64(8), object(17)
# memory usage: 414.4+ KB
# Highland County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7491 entries, 0 to 7490
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   strap         7491 non-null   object
#  1    dsp_strap    7491 non-null   object
#  2    owner        7491 non-null   object
#  3    addr         7265 non-null   object
#  4    nh_cd        7488 non-null   object
#  5   price         7491 non-null   float64
#  6   dos           7491 non-null   object
#  7    qualified    7491 non-null   object
#  8    use_code     7491 non-null   object
#  9    acreage      7491 non-null   float64
#  10   vacant       7491 non-null   object
#  11   year_built   7491 non-null   object
#  12   heated_area  7491 non-null   int64
#  13  Unnamed: 13   22 non-null     float64
# dtypes: float64(3), int64(1), object(10)
# memory usage: 819.5+ KB
# Hillsborough County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2306409 entries, 0 to 2306408
# Data columns (total 17 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   PIN       2306409 non-null  object
#  1   FOLIO     2306409 non-null  object
#  2   DOR_CODE  2306409 non-null  object
#  3   NBHC      2306409 non-null  float64
#  4   S_DATE    2306409 non-null  object
#  5   VI        2306409 non-null  object
#  6   QU        2306409 non-null  object
#  7   REA_CD    2306409 non-null  object
#  8   S_AMT     2306409 non-null  float64
#  9   SUB       2306409 non-null  object
#  10  STR       2306409 non-null  object
#  11  S_TYPE    2306409 non-null  object
#  12  OR_BK     2306409 non-null  object
#  13  OR_PG     2306409 non-null  object
#  14  GRANTOR   2306409 non-null  object
#  15  GRANTEE   2306409 non-null  object
#  16  DOC_NUM   2306409 non-null  object
# dtypes: float64(2), object(15)
# memory usage: 299.1+ MB
# Holmes County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 535 entries, 0 to 534
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Parcel ID             535 non-null    object
#  1   Address               391 non-null    object
#  2   Sale Date             535 non-null    object
#  3   Sale Price            535 non-null    object
#  4   Qualified Sales       535 non-null    object
#  5   Book                  535 non-null    int64
#  6   Page                  535 non-null    int64
#  7   Instrument            534 non-null    object
#  8   Acres                 535 non-null    float64
#  9   Tax District          535 non-null    int64
#  10  Year  Built           275 non-null    float64
#  11  Square Ft             275 non-null    float64
#  12  Sec/Twp/Rng           535 non-null    object
#  13  Sale  Type Alternate  535 non-null    object
# dtypes: float64(3), int64(3), object(8)
# memory usage: 58.6+ KB
# Indian River County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2704 entries, 0 to 2703
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Parcel ID                2704 non-null   float64
#  1   Prop ID                  2704 non-null   int64
#  2   Address                  2704 non-null   object
#  3   Owner Name               2695 non-null   object
#  4   Sale Date                2704 non-null   object
#  5   Sale Price               2704 non-null   object
#  6   Qualified Sales          2704 non-null   object
#  7   Book                     2695 non-null   float64
#  8   Page                     2695 non-null   float64
#  9   Instrument               2704 non-null   object
#  10  Acres                    2704 non-null   float64
#  11  Property Use             2704 non-null   object
#  12  Tax District             2704 non-null   object
#  13  Just Value               2704 non-null   object
#  14  Year  Built              2023 non-null   float64
#  15  Bedrooms                 2023 non-null   float64
#  16  Total  Baths             2023 non-null   float64
#  17  Heated Sq Ft             2023 non-null   float64
#  18  Price Per  Heated SqFt   2704 non-null   object
#  19  Neighborhood             2704 non-null   object
#  20  Subdivision              2629 non-null   object
#  21  Sec/Twp/Rng              2704 non-null   object
#  22  Vacant                   2704 non-null   object
#  23  Building Use             2017 non-null   object
#  24  Land Use                 2236 non-null   object
#  25  Mailing Address          2696 non-null   object
#  26  Site Zip Code            2704 non-null   int64
#  27  Stories                  2704 non-null   int64
# dtypes: float64(8), int64(3), object(17)
# memory usage: 591.6+ KB
# Jackson County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Parcel ID             541 non-null    object
#  1   Address               541 non-null    object
#  2   Sale Date             541 non-null    object
#  3   Sale Price            541 non-null    object
#  4   Qualified Sales       541 non-null    object
#  5   Book                  541 non-null    int64
#  6   Page                  541 non-null    int64
#  7   Instrument            541 non-null    object
#  8   Acres                 541 non-null    float64
#  9   Tax District          541 non-null    int64
#  10  Year  Built           229 non-null    float64
#  11  Square Ft             229 non-null    float64
#  12  Sec/Twp/Rng           541 non-null    object
#  13  Sale  Type Alternate  541 non-null    object
# dtypes: float64(3), int64(3), object(8)
# memory usage: 59.3+ KB
# Jefferson County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 391 entries, 0 to 390
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Parcel ID        391 non-null    object
#  1   Address          391 non-null    object
#  2   Sale Date        391 non-null    object
#  3   Sale Price       391 non-null    object
#  4   Qualified Sales  391 non-null    object
#  5   Reason           391 non-null    object
#  6   Book             391 non-null    int64
#  7   Page             391 non-null    int64
#  8   Instrument       391 non-null    object
#  9   Acres            391 non-null    float64
#  10  Parcel  Class    391 non-null    object
#  11  Tax District     391 non-null    int64
#  12  Year  Built      240 non-null    float64
#  13  Square Ft        240 non-null    float64
#  14  Sec/Twp/Rng      391 non-null    object
#  15  Prop ID          214 non-null    object
# dtypes: float64(3), int64(3), object(10)
# memory usage: 49.0+ KB
# Lake County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26420 entries, 0 to 26419
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   AltKey                     26420 non-null  int64
#  1   ParcelNumber               26293 non-null  object
#  2   OwnerName1                 26285 non-null  object
#  3   OwnerMailAddress1          26269 non-null  object
#  4   OwnerMailAddress2          114 non-null    object
#  5   OwnerMailCity              26269 non-null  object
#  6   OwnerMailState             26171 non-null  object
#  7   OwnerMailZip               26187 non-null  object
#  8   PhysicalStreetAddress      26293 non-null  object
#  9   PhysicalCity               26186 non-null  object
#  10  PhysicalZip                26091 non-null  object
#  11  PropertyUseCode            26293 non-null  float64
#  12  PropertyUseDescription     26293 non-null  object
#  13  SubdivisionName            23705 non-null  object
#  14  MillageGroup               26293 non-null  object
#  15  MillageDescription         26290 non-null  object
#  16  LegalDescription           26293 non-null  object
#  17  SaleDate                   26420 non-null  datetime64[ns]
#  18  SalePrice                  26420 non-null  int64
#  19  SaleInstrument             26420 non-null  object
#  20  SaleInstrumentDescription  26406 non-null  object
#  21  SaleQualify                26420 non-null  object
#  22  SaleQualifyCode            26407 non-null  float64
#  23  SaleVacImprovement         26386 non-null  object
#  24  SaleBookNumber             26418 non-null  float64
#  25  SalePageNumber             26420 non-null  int64
#  26  HeatedSquareFeet           26293 non-null  float64
#  27  YearBuilt                  17610 non-null  float64
#  28  Bedrooms                   17634 non-null  float64
#  29  HalfBaths                  17634 non-null  float64
#  30  FullBathrooms              17634 non-null  float64
#  31  Fireplaces                 17634 non-null  float64
#  32  Pool                       26420 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(3), object(20)
# memory usage: 6.7+ MB
# Leon County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7715 entries, 0 to 7714
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Parcel Id            7715 non-null   object
#  1   Owner                7715 non-null   object
#  2   Address              7715 non-null   object
#  3   Sale Date            7715 non-null   datetime64[ns]
#  4   Sale Price           7715 non-null   int64
#  5   Book/Page            7715 non-null   object
#  6   Instrument Type      7715 non-null   object
#  7   Sale Type            7715 non-null   object
#  8   Base SqFt            5728 non-null   float64
#  9   Aux Sqft             5633 non-null   float64
#  10  Year Built           5728 non-null   float64
#  11  Has Pool             7715 non-null   object
#  12  Property Use         7419 non-null   object
#  13  Acreage              7715 non-null   float64
#  14  Number of Buildings  5728 non-null   float64
#  15  Mailing Address 1    7715 non-null   object
#  16  Mailing Address 2    7715 non-null   object
#  17  Mailing Address 3    98 non-null     object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(11)
# memory usage: 1.1+ MB

# %%
root = 'data/latest_sales_data'

# Initialize an empty dictionary to hold metadata dataframes
metadata_dfs = {}

# Define a function to load a file into a dataframe
def load_metadata_file_to_df(path, filename):
    if filename.endswith('.xlsx') or filename.endswith('.xls'):
        return pd.read_excel(os.path.join(path, filename))
    elif filename.endswith('.csv'):
        return pd.read_csv(os.path.join(path, filename))
    elif filename.endswith('.json') or filename.endswith('.geojson'):
        with open(os.path.join(path, filename)) as f:
            data = json.load(f)
        return pd.json_normalize(data)
    elif filename.endswith('.dbf'):
        dbf = DBF(os.path.join(path, filename))
        return pd.DataFrame(iter(dbf))
    else:
        return None

# Walk through each directory
for root, dirs, files in os.walk('.'):
    for file in files:
        # Only load metadata files
        if 'metadata' in file.lower():
            df = load_metadata_file_to_df(root, file)
            if df is not None:
                # Use the directory name as the key
                key = os.path.basename(root)
                # If key already exists, append the new dataframe
                if key in metadata_dfs:
                    metadata_dfs[key] = pd.concat([metadata_dfs[key], df])
                else:
                    metadata_dfs[key] = df

# %%
for key in metadata_dfs.keys():
    print(key)
    metadata_dfs[key].info(show_counts=True)
# Out:
# Alachua County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Baker County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Bay County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Bradford County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Calhoun County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Charlotte County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Citrus County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Clay County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Collier County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Columbia County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# DeSoto County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Dixie County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Escambia County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Flagler County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Franklin County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Gadsen County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Gilchrist County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Glades County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Gulf County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Hamilton County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Hardee County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Hendry County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Highland County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Hillsborough County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Holmes County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Indian River County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Jackson County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Jefferson County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Lake County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# Leon County
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Original Column Name   3 non-null      object
#  1   Effective Column Name  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes

# %%
# Iterate over each key in the dataframes dictionary
for key in dataframes.keys():
    # Get the current dataframe and its corresponding metadata dataframe
    df = dataframes[key]
    metadata_df = metadata_dfs[key]

    # Create a dictionary mapping original column names to effective column names
    # Use strip to remove leading and trailing spaces
    rename_dict = pd.Series(metadata_df['Effective Column Name'].str.strip().values, index=metadata_df['Original Column Name'].str.strip()).to_dict()

    # Select only the columns that are in the rename_dict keys and rename them
    try:
        dataframes[key] = df[rename_dict.keys()].rename(columns=rename_dict)
    except KeyError as e:
        print(f"Error in {key} metadata: {str(e)}. Please check the 'Original Column Name' in the metadata file.")

# %%
# Concatenate all dataframes in the dictionary
combined_df = pd.concat(dataframes.values(), ignore_index=True)

# %%
combined_df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2470319 entries, 0 to 2470318
# Data columns (total 4 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   ParcelID    127467 non-null   object
#  1   Sale Date   2441977 non-null  object
#  2   Sale Price  2470319 non-null  object
#  3   PIN         2342725 non-null  object
# dtypes: object(4)
# memory usage: 75.4+ MB

# %%
combined_df.to_csv('data/compiled_latest_sales_data.csv', index=False)
